# %%
import pandas as pd
import os
import re
import numpy as np
from collections import defaultdict

# %matplotlib inline

DATA_DIR = "../data/conll2018/task1/all"

# %%
def load_stats(fn):
    maxlen_lemma = 0
    maxlen_infl = 0
    maxlen_tags = 0
    types_lemma = set()
    types_infl = set()
    types_tags = set()
    alphabet = set()
    cnt = 0
    with open(fn) as f:
        for l in f:
            cnt += 1
            lemma, infl, tags = l.rstrip('\n').split('\t')
            tags = tags.split(';')
            maxlen_lemma = max(maxlen_lemma, len(lemma))
            maxlen_infl = max(maxlen_infl, len(infl))
            maxlen_tags = max(maxlen_tags, len(tags))
            alphabet |= set(lemma)
            alphabet |= set(infl)
            types_lemma.add(lemma)
            types_infl.add(infl)
            types_tags |= set(tags)
    return {
        'lemma maxlen': maxlen_lemma,
        'inflected maxlen': maxlen_infl,
        'tags maxlen': maxlen_tags,
        'alphabet size': len(alphabet),
        'lemma types': len(types_lemma),
        'inflected types': len(types_infl),
        'tag types': len(types_tags),
    }
        
stats = []
for fn in os.listdir(DATA_DIR):
    if fn.endswith('train-high'):
        stat = load_stats(os.path.join(DATA_DIR, fn))
        stat['language'] = '-'.join(fn.split('-')[:-2])
    
        stats.append(stat)
    
stats = pd.DataFrame(stats).set_index('language')

# %%
stats.describe()
# Out:
#        alphabet size  inflected maxlen  inflected types  lemma maxlen  \
# count      77.000000         77.000000        77.000000     77.000000
# mean       41.636364         24.025974      7648.571429     18.324675
# std        15.163069         11.033411      2841.278439     10.310242
# min        19.000000         10.000000       631.000000      6.000000
# 25%        30.000000         18.000000      6605.000000     14.000000
# 50%        39.000000         22.000000      9040.000000     17.000000
# 75%        49.000000         27.000000      9737.000000     21.000000
# max       102.000000         90.000000      9994.000000     89.000000
#
#        lemma types  tag types  tags maxlen
# count    77.000000  77.000000    77.000000
# mean   2034.012987  25.740260     6.168831
# std    2237.621802   8.305678     1.922188
# min      15.000000  10.000000     3.000000
# 25%     258.000000  20.000000     5.000000
# 50%     993.000000  25.000000     6.000000
# 75%    3413.000000  32.000000     7.000000
# max    8643.000000  48.000000    14.000000

# %%
print(stats.loc[['breton', 'latin', 'lithuanian']].T.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# language &  breton &  latin &  lithuanian \\
# \midrule
# alphabet size    &      27 &     55 &          58 \\
# inflected maxlen &      14 &     23 &          32 \\
# inflected types  &    1790 &   9896 &        9463 \\
# lemma maxlen     &      11 &     19 &          28 \\
# lemma types      &      44 &   6517 &        1443 \\
# tag types        &      20 &     33 &          34 \\
# tags maxlen      &       9 &      7 &           6 \\
# \bottomrule
# \end{tabular}

# %%
stats.loc[['lithuanian', 'breton', 'latin']].T
# Out:
# language          lithuanian  breton  latin
# alphabet size             58      27     55
# inflected maxlen          32      14     23
# inflected types         9463    1790   9896
# lemma maxlen              28      11     19
# lemma types             1443      44   6517
# tag types                 34      20     33
# tags maxlen                6       9      7

# %%
load_stats(os.path.join(DATA_DIR, "lithuanian-train-high"))
# Out:
# {'alphabet': 58,
#  'maxlen_infl': 32,
#  'maxlen_lemma': 28,
#  'maxlen_tags': 6,
#  'types_infl': 9463,
#  'types_lemma': 1443,
#  'types_tags': 34}

# %%
load_stats(os.path.join(DATA_DIR, "breton-train-high"))
# Out:
# {'alphabet': 27,
#  'maxlen_infl': 14,
#  'maxlen_lemma': 11,
#  'maxlen_tags': 9,
#  'types_infl': 1790,
#  'types_lemma': 44,
#  'types_tags': 20}

# %%
load_stats(os.path.join(DATA_DIR, "hungarian-train-high"))
# Out:
# {'alphabet': 50,
#  'maxlen_infl': 27,
#  'maxlen_lemma': 22,
#  'maxlen_tags': 6,
#  'types_infl': 8917,
#  'types_lemma': 6309,
#  'types_tags': 35}

# %%
column_names = ["lemma", "inflected", "msd"]

hun_df = pd.read_table(os.path.join(DATA_DIR, "hungarian-train-high"), names=column_names)
hun_df.describe()
# Out:
#         lemma inflected          msd
# count   10000     10000        10000
# unique   7123      9954           93
# top     hámoz    plural  N;ON+ESS;SG
# freq        6        24          286

# %%
unimorph_schema = pd.read_csv('https://docs.google.com/spreadsheets/d/1yEqZk13qK_E8CjL1pqIu2k89pRrq503smEY85DFFYEI/export?format=csv')

# %%
unimorph_schema['Label'] = unimorph_schema['Label'].str.upper()
unimorph_schema['Alternatives'] = unimorph_schema['Alternatives'].str.upper()
# unimorph_schema = unimorph_schema.set_index('Label')
unimorph_schema.describe()
# Out:
#        Dimension    Feature Label Alternatives
# count        247        247   247            7
# unique        25        237   246            7
# top         Case  Proximate  PROX     NEGATIVE
# freq          42          3     2            1

# %%
unimorph_update = [
    {'Dimension': 'Case', 'Label': 'LOC'},
]

for u in unimorph_update:
    unimorph_schema = unimorph_schema.append(u, ignore_index=True)

# %%
known_tags = set(unimorph_schema['Alternatives'].dropna().str.split(',', expand=True).values.flatten())
known_tags.discard(None)
known_tags |= set(unimorph_schema['Label'])

tag_freqs = defaultdict(int)
missing_tag_freqs = defaultdict(int)
missing_per_lang = defaultdict(int)

languages = {fn.split("-")[0] for fn in os.listdir(DATA_DIR)}
size = ["high", "medium", "low"]

for fn in os.listdir(DATA_DIR):
    lang = fn.split("-")[0]
    if lang == 'basque':
        continue
    if not "train" in fn:
        continue
    if "low" in fn and "{}-train-medium".format(lang) in os.listdir(DATA_DIR):
        continue
    if "medium" in fn and "{}-train-high".format(lang) in os.listdir(DATA_DIR):
        continue
    df = pd.read_table(os.path.join(DATA_DIR, fn), names=column_names)
    for tags in df['msd']:
        for tag_ in tags.split(";"):
            for tag in re.split(r'[:+/]', tag_):
                if tag.startswith('LGSPEC'):
                    continue
                if tag in known_tags:
                    tag_freqs[tag] += 1
                else:
                    missing_per_lang[lang] += 1
                    missing_tag_freqs[tag] += 1

# %%
print(len(missing_tag_freqs), sum(missing_tag_freqs.values()))
sorted(missing_tag_freqs.items(), key=lambda x: -x[1])[:20]
# Out:
# 106 54896
# [('ARG3', 4115),
#  ('3rd_PERSON_PLURAL', 3356),
#  ('ARGDU', 3306),
#  ('ARGPL', 3222),
#  ('ARG1', 3077),
#  ('PRES', 2911),
#  ('ARGSG', 2646),
#  ('INTERROGATIVE', 2019),
#  ('FUTURE', 2014),
#  ('ARG2', 1982),
#  ('ARGEXCL', 1729),
#  ('HABITUAL', 1242),
#  ('BIASED', 929),
#  ('(non)NOM', 780),
#  ('CERTAIN', 777),
#  ('ARGINCL', 680),
#  ('SIMPLE', 627),
#  ('NON_FACTIVE', 623),
#  ('RELATIVE', 621),
#  ('FREQ', 562)]

# %%
missing_per_lang
# Out:
# defaultdict(int,
#             {'armenian': 329,
#              'bengali': 83,
#              'faroese': 248,
#              'finnish': 57,
#              'greek': 41,
#              'haida': 15630,
#              'hebrew': 413,
#              'irish': 332,
#              'khaling': 20757,
#              'latin': 103,
#              'latvian': 28,
#              'lithuanian': 562,
#              'livonian': 10,
#              'murrinhpatha': 420,
#              'navajo': 587,
#              'old': 41,
#              'pashto': 780,
#              'quechua': 1865,
#              'swahili': 2212,
#              'turkish': 787,
#              'yiddish': 1435,
#              'zulu': 8176})

# %%
hun_df.head()

# hun_df.msd.str.split(';').apply(lambda x: x[0])

nouns = hun_df[hun_df.msd.str[0] == 'N']
noun_cases = set(nouns.msd.str.split(';').apply(lambda x: x[1]))
noun_number = set(['SG', 'PL'])
for n in nouns.msd:
    for tag in n.split(';')[1:]:
        if tag not in noun_cases and tag not in noun_number:
            print("Unknown tag", tag)
            

noun_lemmas = set(nouns['lemma'])
generated = []
for lemma in noun_lemmas:
    for case in noun_cases:
        for number in noun_number:
            msd = 'N;{};{}'.format(case, number)
            generated.append({'lemma': lemma, 'msd': msd})

hun_gen = pd.DataFrame(generated)
hun_gen['inflected'] = None

# %%
hun_gen = hun_gen.iloc[:, [0, 2, 1]]

# %%
hun_gen.to_csv("hun_generated", index=False, header=False, sep="\t")

# %%
def find_dimensions(fn):
    cooc = defaultdict(lambda: defaultdict(int))
    with open(fn) as f:
        for line in f:
            tags = line.strip().split("\t")[2].split(';')
            for i in range(len(tags)-1):
                for j in range(i+1, len(tags)):
                    cooc[tags[i]][tags[j]] += 1
                    cooc[tags[j]][tags[i]] += 1
    cooc_mtx = np.zeros((len(cooc), len(cooc)), dtype=np.int32)
    tag_mapping = {}
    for tag1, co in cooc.items():
        i = tag_mapping.setdefault(tag1, len(tag_mapping))
        for tag2, fr in co.items():
            j = tag_mapping.setdefault(tag2, len(tag_mapping))
            cooc_mtx[i, j] += fr
            cooc_mtx[j, i] += fr
    return cooc_mtx, tag_mapping

m, mapping = find_dimensions("../data/conll2018/task1/all/hungarian-train-medium")

# %%
inv_mapping = {v: k for k, v in mapping.items()}
for i, j in zip(*np.where(m == 0)):
    if i == j:
        continue
    print(inv_mapping[i], inv_mapping[j])
# Out:
# N V
# N COND
# N PRS
# N DEF
# N 1
# N SBJV
# N INDF
# N 2
# N 3
# N IND
# N PST
# N NFIN
# N V.PTCP
# N FUT
# ON+ABL IN+ALL
# ON+ABL IN+ESS
# ON+ABL DAT
# ON+ABL TERM
# ON+ABL INST
# ON+ABL AT+ALL
# ON+ABL FRML
# ON+ABL ACC
# ON+ABL AT+ESS
# ON+ABL TRANS
# ON+ABL IN+ABL
# ON+ABL ON+ALL
# ON+ABL AT+ABL
# ON+ABL ON+ESS
# ON+ABL PRP
# ON+ABL NOM
# ON+ABL V
# ON+ABL COND
# ON+ABL PRS
# ON+ABL DEF
# ON+ABL 1
# ON+ABL SBJV
# ON+ABL INDF
# ON+ABL 2
# ON+ABL 3
# ON+ABL IND
# ON+ABL PST
# ON+ABL NFIN
# ON+ABL V.PTCP
# ON+ABL FUT
# PL SG
# PL V.PTCP
# PL FUT
# IN+ALL ON+ABL
# IN+ALL IN+ESS
# IN+ALL DAT
# IN+ALL TERM
# IN+ALL INST
# IN+ALL AT+ALL
# IN+ALL FRML
# IN+ALL ACC
# IN+ALL AT+ESS
# IN+ALL TRANS
# IN+ALL IN+ABL
# IN+ALL ON+ALL
# IN+ALL AT+ABL
# IN+ALL ON+ESS
# IN+ALL PRP
# IN+ALL NOM
# IN+ALL V
# IN+ALL COND
# IN+ALL PRS
# IN+ALL DEF
# IN+ALL 1
# IN+ALL SBJV
# IN+ALL INDF
# IN+ALL 2
# IN+ALL 3
# IN+ALL IND
# IN+ALL PST
# IN+ALL NFIN
# IN+ALL V.PTCP
# IN+ALL FUT
# IN+ESS ON+ABL
# IN+ESS IN+ALL
# IN+ESS DAT
# IN+ESS TERM
# IN+ESS INST
# IN+ESS AT+ALL
# IN+ESS FRML
# IN+ESS ACC
# IN+ESS AT+ESS
# IN+ESS TRANS
# IN+ESS IN+ABL
# IN+ESS ON+ALL
# IN+ESS AT+ABL
# IN+ESS ON+ESS
# IN+ESS PRP
# IN+ESS NOM
# IN+ESS V
# IN+ESS COND
# IN+ESS PRS
# IN+ESS DEF
# IN+ESS 1
# IN+ESS SBJV
# IN+ESS INDF
# IN+ESS 2
# IN+ESS 3
# IN+ESS IND
# IN+ESS PST
# IN+ESS NFIN
# IN+ESS V.PTCP
# IN+ESS FUT
# SG PL
# SG V.PTCP
# SG FUT
# DAT ON+ABL
# DAT IN+ALL
# DAT IN+ESS
# DAT TERM
# DAT INST
# DAT AT+ALL
# DAT FRML
# DAT ACC
# DAT AT+ESS
# DAT TRANS
# DAT IN+ABL
# DAT ON+ALL
# DAT AT+ABL
# DAT ON+ESS
# DAT PRP
# DAT NOM
# DAT V
# DAT COND
# DAT PRS
# DAT DEF
# DAT 1
# DAT SBJV
# DAT INDF
# DAT 2
# DAT 3
# DAT IND
# DAT PST
# DAT NFIN
# DAT V.PTCP
# DAT FUT
# TERM ON+ABL
# TERM IN+ALL
# TERM IN+ESS
# TERM DAT
# TERM INST
# TERM AT+ALL
# TERM FRML
# TERM ACC
# TERM AT+ESS
# TERM TRANS
# TERM IN+ABL
# TERM ON+ALL
# TERM AT+ABL
# TERM ON+ESS
# TERM PRP
# TERM NOM
# TERM V
# TERM COND
# TERM PRS
# TERM DEF
# TERM 1
# TERM SBJV
# TERM INDF
# TERM 2
# TERM 3
# TERM IND
# TERM PST
# TERM NFIN
# TERM V.PTCP
# TERM FUT
# INST ON+ABL
# INST IN+ALL
# INST IN+ESS
# INST DAT
# INST TERM
# INST AT+ALL
# INST FRML
# INST ACC
# INST AT+ESS
# INST TRANS
# INST IN+ABL
# INST ON+ALL
# INST AT+ABL
# INST ON+ESS
# INST PRP
# INST NOM
# INST V
# INST COND
# INST PRS
# INST DEF
# INST 1
# INST SBJV
# INST INDF
# INST 2
# INST 3
# INST IND
# INST PST
# INST NFIN
# INST V.PTCP
# INST FUT
# AT+ALL ON+ABL
# AT+ALL IN+ALL
# AT+ALL IN+ESS
# AT+ALL DAT
# AT+ALL TERM
# AT+ALL INST
# AT+ALL FRML
# AT+ALL ACC
# AT+ALL AT+ESS
# AT+ALL TRANS
# AT+ALL IN+ABL
# AT+ALL ON+ALL
# AT+ALL AT+ABL
# AT+ALL ON+ESS
# AT+ALL PRP
# AT+ALL NOM
# AT+ALL V
# AT+ALL COND
# AT+ALL PRS
# AT+ALL DEF
# AT+ALL 1
# AT+ALL SBJV
# AT+ALL INDF
# AT+ALL 2
# AT+ALL 3
# AT+ALL IND
# AT+ALL PST
# AT+ALL NFIN
# AT+ALL V.PTCP
# AT+ALL FUT
# FRML ON+ABL
# FRML IN+ALL
# FRML IN+ESS
# FRML DAT
# FRML TERM
# FRML INST
# FRML AT+ALL
# FRML ACC
# FRML AT+ESS
# FRML TRANS
# FRML IN+ABL
# FRML ON+ALL
# FRML AT+ABL
# FRML ON+ESS
# FRML PRP
# FRML NOM
# FRML V
# FRML COND
# FRML PRS
# FRML DEF
# FRML 1
# FRML SBJV
# FRML INDF
# FRML 2
# FRML 3
# FRML IND
# FRML PST
# FRML NFIN
# FRML V.PTCP
# FRML FUT
# ACC ON+ABL
# ACC IN+ALL
# ACC IN+ESS
# ACC DAT
# ACC TERM
# ACC INST
# ACC AT+ALL
# ACC FRML
# ACC AT+ESS
# ACC TRANS
# ACC IN+ABL
# ACC ON+ALL
# ACC AT+ABL
# ACC ON+ESS
# ACC PRP
# ACC NOM
# ACC V
# ACC COND
# ACC PRS
# ACC DEF
# ACC 1
# ACC SBJV
# ACC INDF
# ACC 2
# ACC 3
# ACC IND
# ACC PST
# ACC NFIN
# ACC V.PTCP
# ACC FUT
# AT+ESS ON+ABL
# AT+ESS IN+ALL
# AT+ESS IN+ESS
# AT+ESS DAT
# AT+ESS TERM
# AT+ESS INST
# AT+ESS AT+ALL
# AT+ESS FRML
# AT+ESS ACC
# AT+ESS TRANS
# AT+ESS IN+ABL
# AT+ESS ON+ALL
# AT+ESS AT+ABL
# AT+ESS ON+ESS
# AT+ESS PRP
# AT+ESS NOM
# AT+ESS V
# AT+ESS COND
# AT+ESS PRS
# AT+ESS DEF
# AT+ESS 1
# AT+ESS SBJV
# AT+ESS INDF
# AT+ESS 2
# AT+ESS 3
# AT+ESS IND
# AT+ESS PST
# AT+ESS NFIN
# AT+ESS V.PTCP
# AT+ESS FUT
# TRANS ON+ABL
# TRANS IN+ALL
# TRANS IN+ESS
# TRANS DAT
# TRANS TERM
# TRANS INST
# TRANS AT+ALL
# TRANS FRML
# TRANS ACC
# TRANS AT+ESS
# TRANS IN+ABL
# TRANS ON+ALL
# TRANS AT+ABL
# TRANS ON+ESS
# TRANS PRP
# TRANS NOM
# TRANS V
# TRANS COND
# TRANS PRS
# TRANS DEF
# TRANS 1
# TRANS SBJV
# TRANS INDF
# TRANS 2
# TRANS 3
# TRANS IND
# TRANS PST
# TRANS NFIN
# TRANS V.PTCP
# TRANS FUT
# IN+ABL ON+ABL
# IN+ABL IN+ALL
# IN+ABL IN+ESS
# IN+ABL DAT
# IN+ABL TERM
# IN+ABL INST
# IN+ABL AT+ALL
# IN+ABL FRML
# IN+ABL ACC
# IN+ABL AT+ESS
# IN+ABL TRANS
# IN+ABL ON+ALL
# IN+ABL AT+ABL
# IN+ABL ON+ESS
# IN+ABL PRP
# IN+ABL NOM
# IN+ABL V
# IN+ABL COND
# IN+ABL PRS
# IN+ABL DEF
# IN+ABL 1
# IN+ABL SBJV
# IN+ABL INDF
# IN+ABL 2
# IN+ABL 3
# IN+ABL IND
# IN+ABL PST
# IN+ABL NFIN
# IN+ABL V.PTCP
# IN+ABL FUT
# ON+ALL ON+ABL
# ON+ALL IN+ALL
# ON+ALL IN+ESS
# ON+ALL DAT
# ON+ALL TERM
# ON+ALL INST
# ON+ALL AT+ALL
# ON+ALL FRML
# ON+ALL ACC
# ON+ALL AT+ESS
# ON+ALL TRANS
# ON+ALL IN+ABL
# ON+ALL AT+ABL
# ON+ALL ON+ESS
# ON+ALL PRP
# ON+ALL NOM
# ON+ALL V
# ON+ALL COND
# ON+ALL PRS
# ON+ALL DEF
# ON+ALL 1
# ON+ALL SBJV
# ON+ALL INDF
# ON+ALL 2
# ON+ALL 3
# ON+ALL IND
# ON+ALL PST
# ON+ALL NFIN
# ON+ALL V.PTCP
# ON+ALL FUT
# AT+ABL ON+ABL
# AT+ABL IN+ALL
# AT+ABL IN+ESS
# AT+ABL DAT
# AT+ABL TERM
# AT+ABL INST
# AT+ABL AT+ALL
# AT+ABL FRML
# AT+ABL ACC
# AT+ABL AT+ESS
# AT+ABL TRANS
# AT+ABL IN+ABL
# AT+ABL ON+ALL
# AT+ABL ON+ESS
# AT+ABL PRP
# AT+ABL NOM
# AT+ABL V
# AT+ABL COND
# AT+ABL PRS
# AT+ABL DEF
# AT+ABL 1
# AT+ABL SBJV
# AT+ABL INDF
# AT+ABL 2
# AT+ABL 3
# AT+ABL IND
# AT+ABL PST
# AT+ABL NFIN
# AT+ABL V.PTCP
# AT+ABL FUT
# ON+ESS ON+ABL
# ON+ESS IN+ALL
# ON+ESS IN+ESS
# ON+ESS DAT
# ON+ESS TERM
# ON+ESS INST
# ON+ESS AT+ALL
# ON+ESS FRML
# ON+ESS ACC
# ON+ESS AT+ESS
# ON+ESS TRANS
# ON+ESS IN+ABL
# ON+ESS ON+ALL
# ON+ESS AT+ABL
# ON+ESS PRP
# ON+ESS NOM
# ON+ESS V
# ON+ESS COND
# ON+ESS PRS
# ON+ESS DEF
# ON+ESS 1
# ON+ESS SBJV
# ON+ESS INDF
# ON+ESS 2
# ON+ESS 3
# ON+ESS IND
# ON+ESS PST
# ON+ESS NFIN
# ON+ESS V.PTCP
# ON+ESS FUT
# PRP ON+ABL
# PRP IN+ALL
# PRP IN+ESS
# PRP DAT
# PRP TERM
# PRP INST
# PRP AT+ALL
# PRP FRML
# PRP ACC
# PRP AT+ESS
# PRP TRANS
# PRP IN+ABL
# PRP ON+ALL
# PRP AT+ABL
# PRP ON+ESS
# PRP NOM
# PRP V
# PRP COND
# PRP PRS
# PRP DEF
# PRP 1
# PRP SBJV
# PRP INDF
# PRP 2
# PRP 3
# PRP IND
# PRP PST
# PRP NFIN
# PRP V.PTCP
# PRP FUT
# NOM ON+ABL
# NOM IN+ALL
# NOM IN+ESS
# NOM DAT
# NOM TERM
# NOM INST
# NOM AT+ALL
# NOM FRML
# NOM ACC
# NOM AT+ESS
# NOM TRANS
# NOM IN+ABL
# NOM ON+ALL
# NOM AT+ABL
# NOM ON+ESS
# NOM PRP
# NOM V
# NOM COND
# NOM PRS
# NOM DEF
# NOM 1
# NOM SBJV
# NOM INDF
# NOM 2
# NOM 3
# NOM IND
# NOM PST
# NOM NFIN
# NOM V.PTCP
# NOM FUT
# V N
# V ON+ABL
# V IN+ALL
# V IN+ESS
# V DAT
# V TERM
# V INST
# V AT+ALL
# V FRML
# V ACC
# V AT+ESS
# V TRANS
# V IN+ABL
# V ON+ALL
# V AT+ABL
# V ON+ESS
# V PRP
# V NOM
# V V.PTCP
# V FUT
# COND N
# COND ON+ABL
# COND IN+ALL
# COND IN+ESS
# COND DAT
# COND TERM
# COND INST
# COND AT+ALL
# COND FRML
# COND ACC
# COND AT+ESS
# COND TRANS
# COND IN+ABL
# COND ON+ALL
# COND AT+ABL
# COND ON+ESS
# COND PRP
# COND NOM
# COND SBJV
# COND IND
# COND PST
# COND NFIN
# COND V.PTCP
# COND FUT
# PRS N
# PRS ON+ABL
# PRS IN+ALL
# PRS IN+ESS
# PRS DAT
# PRS TERM
# PRS INST
# PRS AT+ALL
# PRS FRML
# PRS ACC
# PRS AT+ESS
# PRS TRANS
# PRS IN+ABL
# PRS ON+ALL
# PRS AT+ABL
# PRS ON+ESS
# PRS PRP
# PRS NOM
# PRS PST
# PRS NFIN
# PRS FUT
# DEF N
# DEF ON+ABL
# DEF IN+ALL
# DEF IN+ESS
# DEF DAT
# DEF TERM
# DEF INST
# DEF AT+ALL
# DEF FRML
# DEF ACC
# DEF AT+ESS
# DEF TRANS
# DEF IN+ABL
# DEF ON+ALL
# DEF AT+ABL
# DEF ON+ESS
# DEF PRP
# DEF NOM
# DEF INDF
# DEF NFIN
# DEF V.PTCP
# DEF FUT
# 1 N
# 1 ON+ABL
# 1 IN+ALL
# 1 IN+ESS
# 1 DAT
# 1 TERM
# 1 INST
# 1 AT+ALL
# 1 FRML
# 1 ACC
# 1 AT+ESS
# 1 TRANS
# 1 IN+ABL
# 1 ON+ALL
# 1 AT+ABL
# 1 ON+ESS
# 1 PRP
# 1 NOM
# 1 2
# 1 3
# 1 V.PTCP
# 1 FUT
# SBJV N
# SBJV ON+ABL
# SBJV IN+ALL
# SBJV IN+ESS
# SBJV DAT
# SBJV TERM
# SBJV INST
# SBJV AT+ALL
# SBJV FRML
# SBJV ACC
# SBJV AT+ESS
# SBJV TRANS
# SBJV IN+ABL
# SBJV ON+ALL
# SBJV AT+ABL
# SBJV ON+ESS
# SBJV PRP
# SBJV NOM
# SBJV COND
# SBJV IND
# SBJV PST
# SBJV NFIN
# SBJV V.PTCP
# SBJV FUT
# INDF N
# INDF ON+ABL
# INDF IN+ALL
# INDF IN+ESS
# INDF DAT
# INDF TERM
# INDF INST
# INDF AT+ALL
# INDF FRML
# INDF ACC
# INDF AT+ESS
# INDF TRANS
# INDF IN+ABL
# INDF ON+ALL
# INDF AT+ABL
# INDF ON+ESS
# INDF PRP
# INDF NOM
# INDF DEF
# INDF NFIN
# INDF V.PTCP
# INDF FUT
# 2 N
# 2 ON+ABL
# 2 IN+ALL
# 2 IN+ESS
# 2 DAT
# 2 TERM
# 2 INST
# 2 AT+ALL
# 2 FRML
# 2 ACC
# 2 AT+ESS
# 2 TRANS
# 2 IN+ABL
# 2 ON+ALL
# 2 AT+ABL
# 2 ON+ESS
# 2 PRP
# 2 NOM
# 2 1
# 2 3
# 2 V.PTCP
# 2 FUT
# 3 N
# 3 ON+ABL
# 3 IN+ALL
# 3 IN+ESS
# 3 DAT
# 3 TERM
# 3 INST
# 3 AT+ALL
# 3 FRML
# 3 ACC
# 3 AT+ESS
# 3 TRANS
# 3 IN+ABL
# 3 ON+ALL
# 3 AT+ABL
# 3 ON+ESS
# 3 PRP
# 3 NOM
# 3 1
# 3 2
# 3 V.PTCP
# 3 FUT
# IND N
# IND ON+ABL
# IND IN+ALL
# IND IN+ESS
# IND DAT
# IND TERM
# IND INST
# IND AT+ALL
# IND FRML
# IND ACC
# IND AT+ESS
# IND TRANS
# IND IN+ABL
# IND ON+ALL
# IND AT+ABL
# IND ON+ESS
# IND PRP
# IND NOM
# IND COND
# IND SBJV
# IND NFIN
# IND V.PTCP
# IND FUT
# PST N
# PST ON+ABL
# PST IN+ALL
# PST IN+ESS
# PST DAT
# PST TERM
# PST INST
# PST AT+ALL
# PST FRML
# PST ACC
# PST AT+ESS
# PST TRANS
# PST IN+ABL
# PST ON+ALL
# PST AT+ABL
# PST ON+ESS
# PST PRP
# PST NOM
# PST COND
# PST PRS
# PST SBJV
# PST NFIN
# PST FUT
# NFIN N
# NFIN ON+ABL
# NFIN IN+ALL
# NFIN IN+ESS
# NFIN DAT
# NFIN TERM
# NFIN INST
# NFIN AT+ALL
# NFIN FRML
# NFIN ACC
# NFIN AT+ESS
# NFIN TRANS
# NFIN IN+ABL
# NFIN ON+ALL
# NFIN AT+ABL
# NFIN ON+ESS
# NFIN PRP
# NFIN NOM
# NFIN COND
# NFIN PRS
# NFIN DEF
# NFIN SBJV
# NFIN INDF
# NFIN IND
# NFIN PST
# NFIN V.PTCP
# NFIN FUT
# V.PTCP N
# V.PTCP ON+ABL
# V.PTCP PL
# V.PTCP IN+ALL
# V.PTCP IN+ESS
# V.PTCP SG
# V.PTCP DAT
# V.PTCP TERM
# V.PTCP INST
# V.PTCP AT+ALL
# V.PTCP FRML
# V.PTCP ACC
# V.PTCP AT+ESS
# V.PTCP TRANS
# V.PTCP IN+ABL
# V.PTCP ON+ALL
# V.PTCP AT+ABL
# V.PTCP ON+ESS
# V.PTCP PRP
# V.PTCP NOM
# V.PTCP V
# V.PTCP COND
# V.PTCP DEF
# V.PTCP 1
# V.PTCP SBJV
# V.PTCP INDF
# V.PTCP 2
# V.PTCP 3
# V.PTCP IND
# V.PTCP NFIN
# FUT N
# FUT ON+ABL
# FUT PL
# FUT IN+ALL
# FUT IN+ESS
# FUT SG
# FUT DAT
# FUT TERM
# FUT INST
# FUT AT+ALL
# FUT FRML
# FUT ACC
# FUT AT+ESS
# FUT TRANS
# FUT IN+ABL
# FUT ON+ALL
# FUT AT+ABL
# FUT ON+ESS
# FUT PRP
# FUT NOM
# FUT V
# FUT COND
# FUT PRS
# FUT DEF
# FUT 1
# FUT SBJV
# FUT INDF
# FUT 2
# FUT 3
# FUT IND
# FUT PST
# FUT NFIN
